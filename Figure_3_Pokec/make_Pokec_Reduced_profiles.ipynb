# %% [markdown]
# Preprocesses the profile information from the Pokec social network dataset obtained from: https://snap.stanford.edu/data/soc-Pokec.html
#
# In this notebook we:
# 1. Read in the profile information.
# 2. Reduce the data down to a subset of the attributes.
# 3. Use a geocoder to add lat/lon coordinates assoicated with region names.
#
# Created on: 21/12/19

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import numpy as np
import time
import tqdm

# %%
path_to_profiles = 'Data/raw_data/soc-pokec-profiles.txt'
path_to_edge_list = 'Data/raw_data/soc-pokec-relationships.txt'
column_name_data = 'Data/raw_data/pokec_column_names.txt'

# %% [markdown]
# Read in the profile information with all of the attributes. We read in the following columns:
# - 0 : user
# - 3 : gender
# - 4 : region
# - 7 : age
#
# Note: trying to read in the entire dataframe will usually lead to a memory error.

# %%
columns_of_interest=[0,3,4,7]
data = pd.read_csv(path_to_profiles, sep='\t',header=None,usecols=columns_of_interest)
data.columns = ['user_id','gender','region','age']
data
# Out:
#          user_id  gender                                       region   age
# 0              1     1.0                        zilinsky kraj, zilina  26.0
# 1              2     0.0            zilinsky kraj, kysucke nove mesto   0.0
# 2             16     1.0            zilinsky kraj, kysucke nove mesto  23.0
# 3              3     1.0  bratislavsky kraj, bratislava - karlova ves  29.0
# 4              4     0.0                 banskobystricky kraj, brezno  26.0
# ...          ...     ...                                          ...   ...
# 1632798  1632799     0.0                 banskobystricky kraj, revuca  23.0
# 1632799  1632800     1.0                     trenciansky kraj, myjava  33.0
# 1632800  1632801     1.0                kosicky kraj, kosice - okolie   0.0
# 1632801  1632802     1.0  bratislavsky kraj, bratislava - karlova ves  19.0
# 1632802  1632803     0.0               kosicky kraj, kosice - ostatne  44.0
#
# [1632803 rows x 4 columns]

# %% [markdown]
# # Add lat/lng coordinates

# %% [markdown]
# In order to visualise the data we can identify lat/lon coordinates associated with each of the regions. We can use this by using the Nominatim geocoder from the geopy library. We also screen out the following exceptions:
#
# - outlands='zahranicie' in Slovak.
# - There are also several locations in the Czech Republic (ceska republika, cz).
#
# We replace the coordinates with Nans in these cases.

# %%
#geolocator = Nominatim(user_agent="specify_your_app_name_here")
#https://github.com/geopy/geopy/issues/314 - suggests changing the name of user agent.
geolocator = Nominatim(user_agent="abcd")

#Get the list of unique locations sot hat we do not call the API too many times:
locations = list(data['region'])
location_set = list(set(locations))
print("There are {} unique locations".format(len(location_set)))
num_locations = len(locations)


location_coords = { } #dictionary to store the locations in
q = 0 
for k in tqdm.tqdm_notebook(location_set) :
    q = q + 1
    print(k)
    try:
        if 'zahranicie' in k :
            print("Fails due to 'outlands' at line {}".format(q))
            location_coords[k] = [float('NaN'),float('NaN')]
        elif 'ceska republika, cz' in k :
            print("In ceska republica")
            loc_name = k.split(' - ')[1]
            print("town = " + loc_name )
            print("")
            loc = geolocator.geocode(loc_name,timeout=10)
            location_coords[k] = [loc.latitude,loc.longitude]
        else :
            loc = geolocator.geocode(k,timeout=10)
            location_coords[k] = [loc.latitude,loc.longitude]
        
    
    except TypeError:
        print(f"Failed due to type of {k}")
        location_coords[k] = [float('NaN'),float('NaN')]
        
    except AttributeError :
        print(f"Failed due to attribute error with k = {k}")
        location_coords[k] = [float('NaN'),float('NaN')]
        
    #print("Failed at place = {} , q = {}  due to another error".format(k,q) )
    #print("Sleeping...")
    time.sleep(2.0) # sleep to stop geocoder timeout
    #location_coords[k] = [float('NaN'),float('NaN')]
        
#Now add to the full set of coordinates:
locations = list(data['region'])
user_lat = [ ]
user_lon = [ ]
for loc_name in locations : 
    user_lat.append(location_coords[loc_name][0])
    user_lon.append(location_coords[loc_name][1])
# Out:
# There are 188 unique locations
# HBox(children=(IntProgress(value=0, max=188), HTML(value='')))
# nan
# Failed due to type of nan
# trenciansky kraj, bojnice
# presovsky kraj, bardejov
# trnavsky kraj, trnava
# trenciansky kraj, dubnica nad vahom
# trenciansky kraj, stara tura
# ceska republika, cz - karlovarsky kraj
# In ceska republica
# town = karlovarsky kraj
#
# zilinsky kraj, rajec
# zilinsky kraj, vrutky
# kosicky kraj, dobsina
# nitriansky kraj, vrable
# banskobystricky kraj, brezno
# banskobystricky kraj, kremnica
# ceska republika, cz - ustecky kraj
# In ceska republica
# town = ustecky kraj
#
# nitriansky kraj, levice
# zilinsky kraj, namestovo
# trnavsky kraj, vrbove
# banskobystricky kraj, lucenec
# nitriansky kraj, tlmace
# nitriansky kraj, nitra
# bratislavsky kraj, bratislava - nove mesto
# zilinsky kraj, ruzomberok
# banskobystricky kraj, velky krtis
# banskobystricky kraj, sliac
# kosicky kraj, trebisov
# zahranicie, zahranicie - gb
# Fails due to 'outlands' at line 26
# bratislavsky kraj, bratislava - karlova ves
# kosicky kraj, kosice - ostatne
# presovsky kraj, spisska bela
# banskobystricky kraj, modry kamen
# presovsky kraj, medzilaborce
# banskobystricky kraj, detva
# zilinsky kraj, kysucke nove mesto
# nitriansky kraj, komarno
# zahranicie, bratislava - okolie
# Fails due to 'outlands' at line 35
# banskobystricky kraj, ziar nad hronom
# trenciansky kraj, partizanske
# banskobystricky kraj, banska bystrica
# presovsky kraj, lipany
# kosicky kraj, moldava nad bodvou
# zilinsky kraj, dolny kubin
# nitriansky kraj, nove zamky
# kosicky kraj, kosice - stare mesto
# nitriansky kraj, zeliezovce
# bratislavsky kraj, svaty jur
# trnavsky kraj, sered
# kosicky kraj, spisska nova ves
# trnavsky kraj, galanta
# bratislavsky kraj, bratislava - vrakuna
# presovsky kraj, snina
# ceska republika, cz - stredni cechy
# In ceska republica
# town = stredni cechy
#
# zahranicie, zahranicie - francuzsko
# Fails due to 'outlands' at line 52
# nitriansky kraj, sahy
# trnavsky kraj, dunajska streda
# ceska republika, cz - olomoucky kraj
# In ceska republica
# town = olomoucky kraj
#
# zahranicie, bratislava - stare mesto
# Fails due to 'outlands' at line 56
# kosicky kraj, kosice - sever
# kosicky kraj, spisske vlachy
# presovsky kraj, presov
# ceska republika, cz - pardubicky kraj
# In ceska republica
# town = pardubicky kraj
#
# kosicky kraj, kosice - saca
# bratislavsky kraj, bratislava - petrzalka
# zilinsky kraj, martin
# trenciansky kraj, banovce nad bebravou
# banskobystricky kraj, tisovec
# zilinsky kraj, rajecke teplice
# presovsky kraj, hanusovce nad toplou
# ceska republika, cz - praha
# In ceska republica
# town = praha
#
# banskobystricky kraj, filakovo
# zahranicie, zahranicie - kanada
# Fails due to 'outlands' at line 70
# banskobystricky kraj, zarnovica
# bratislavsky kraj, bratislava - ruzinov
# ceska republika, cz - vysocina
# In ceska republica
# town = vysocina
#
# ceska republika, cz - ostravsky kraj
# In ceska republica
# town = ostravsky kraj
#
# kosicky kraj, kosice - juh
# presovsky kraj, spisska stara ves
# zahranicie, zahranicie - australia
# Fails due to 'outlands' at line 77
# zilinsky kraj, bytca
# ceska republika, cz - zlinsky kraj
# In ceska republica
# town = zlinsky kraj
#
# zilinsky kraj, liptovsky mikulas
# trnavsky kraj, hlohovec
# zahranicie, zahranicie - ostatne
# Fails due to 'outlands' at line 82
# banskobystricky kraj, dudince
# kosicky kraj, cierna nad tisou
# ceska republika, cz - kralovehradecky kraj
# In ceska republica
# town = kralovehradecky kraj
#
# trnavsky kraj, skalica
# kosicky kraj, kosice - sidlisko tahanovce
# trenciansky kraj, povazska bystrica
# presovsky kraj, vysoke tatry
# zilinsky kraj, tvrdosin
# bratislavsky kraj, bratislava - lamac
# banskobystricky kraj, revuca
# banskobystricky kraj, rimavska sobota
# trenciansky kraj, nova dubnica
# bratislavsky kraj, bratislava - stare mesto
# trenciansky kraj, novaky
# bratislavsky kraj, pezinok
# bratislavsky kraj, senec
# kosicky kraj, velke kapusany
# kosicky kraj, kosice - dargovskych hrdinov
# presovsky kraj, podolinec
# trenciansky kraj, ilava
# trenciansky kraj, trencianske teplice
# kosicky kraj, kosice - krasna nad hornadom
# trnavsky kraj, gbely
# nitriansky kraj, surany
# trenciansky kraj, handlova
# banskobystricky kraj, poltar
# kosicky kraj, kralovsky chlmec
# presovsky kraj, svit
# banskobystricky kraj, tornala
# bratislavsky kraj, bratislava - okolie
# bratislavsky kraj, bratislava - ostatne
# Failed due to attribute error with k = bratislavsky kraj, bratislava - ostatne
# nitriansky kraj, sala
# zilinsky kraj, trstena
# presovsky kraj, levoca
# trenciansky kraj, nemsova
# trnavsky kraj, holic
# banskobystricky kraj, hrinova
# banskobystricky kraj, zvolen
# nitriansky kraj, hurbanovo
# trnavsky kraj, sladkovicovo
# zilinsky kraj, krasno nad kysucou
# kosicky kraj, kosice - zapad
# trnavsky kraj, piestany
# presovsky kraj, vranov nad toplou
# presovsky kraj, poprad
# kosicky kraj, michalovce
# presovsky kraj, sabinov
# trnavsky kraj, senica
# zilinsky kraj, turzovka
# presovsky kraj, kezmarok
# ceska republika, cz - jihomoravsky kraj
# In ceska republica
# town = jihomoravsky kraj
#
# trnavsky kraj, sastin-straze
# nitriansky kraj, kolarovo
# trenciansky kraj, brezova pod bradlom
# trenciansky kraj, myjava
# zahranicie, zahranicie - nemecko
# Fails due to 'outlands' at line 138
# presovsky kraj, velky saris
# banskobystricky kraj, hnusta
# trnavsky kraj, samorin
# trnavsky kraj, velky meder
# ceska republika, cz - plzensky kraj
# In ceska republica
# town = plzensky kraj
#
# kosicky kraj, sobrance
# zilinsky kraj, turcianske teplice
# kosicky kraj,
# bratislavsky kraj, bratislava - dubravka
# banskobystricky kraj, krupina
# kosicky kraj, medzev
# nitriansky kraj, topolcany
# kosicky kraj, krompachy
# kosicky kraj, strazske
# zilinsky kraj, zilina
# ceska republika, cz - liberecky kraj
# In ceska republica
# town = liberecky kraj
#
# bratislavsky kraj, bratislava - devinska nova ves
# kosicky kraj, brezova pod bradlom
# Failed due to attribute error with k = kosicky kraj, brezova pod bradlom
# bratislavsky kraj, bratislava - vajnory
# kosicky kraj, kosice - barca
# presovsky kraj, spisske podhradie
# kosicky kraj, gelnica
# presovsky kraj, humenne
# kosicky kraj, kosice - okolie
# ceska republika, cz - budejovicky kraj
# In ceska republica
# town = budejovicky kraj
#
# trnavsky kraj, leopoldov
# banskobystricky kraj, nova bana
# bratislavsky kraj, modra
# kosicky kraj, roznava
# zahranicie, zahranicie - rakusko
# Fails due to 'outlands' at line 168
# banskobystricky kraj, banska stiavnica
# zilinsky kraj, liptovsky hradok
# presovsky kraj, giraltovce
# bratislavsky kraj, bratislava - podunaj. biskupice
# Failed due to attribute error with k = bratislavsky kraj, bratislava - podunaj. biskupice
# trenciansky kraj, prievidza
# trenciansky kraj, puchov
# kosicky kraj, secovce
# nitriansky kraj, sturovo
# zilinsky kraj, cadca
# nitriansky kraj, zlate moravce
# trenciansky kraj, trencin
# trenciansky kraj, nove mesto nad vahom
# presovsky kraj, stropkov
# bratislavsky kraj, malacky
# bratislavsky kraj, stupava
# bratislavsky kraj, bratislava - raca
# presovsky kraj, svidnik
# zahranicie, zahranicie - usa
# Fails due to 'outlands' at line 186
# banskobystricky kraj, jelsava
# presovsky kraj, stara lubovna

# %%
data['user_lat'] = user_lat
data['user_lon'] = user_lon
data
# Out:
#          user_id  gender                                       region   age  \
# 0              1     1.0                        zilinsky kraj, zilina  26.0
# 1              2     0.0            zilinsky kraj, kysucke nove mesto   0.0
# 2             16     1.0            zilinsky kraj, kysucke nove mesto  23.0
# 3              3     1.0  bratislavsky kraj, bratislava - karlova ves  29.0
# 4              4     0.0                 banskobystricky kraj, brezno  26.0
# ...          ...     ...                                          ...   ...
# 1632798  1632799     0.0                 banskobystricky kraj, revuca  23.0
# 1632799  1632800     1.0                     trenciansky kraj, myjava  33.0
# 1632800  1632801     1.0                kosicky kraj, kosice - okolie   0.0
# 1632801  1632802     1.0  bratislavsky kraj, bratislava - karlova ves  19.0
# 1632802  1632803     0.0               kosicky kraj, kosice - ostatne  44.0
#
#           user_lat   user_lon
# 0        49.223467  18.739314
# 1        49.299918  18.786508
# 2        49.299918  18.786508
# 3        48.159240  17.052677
# 4        48.839444  19.664230
# ...            ...        ...
# 1632798  48.698845  20.102171
# 1632799  48.754081  17.576513
# 1632800  48.698393  20.973902
# 1632801  48.159240  17.052677
# 1632802  48.751331  21.856497
#
# [1632803 rows x 6 columns]

# %% [markdown]
# # Save the data

# %%
data.to_csv("Data/reduced_pokec_profiles.csv")

# %%
fraction_missing = np.sum(data[['user_lat']].isnull())/len(data)
print(f"Missing lats = {100*fraction_missing} %")
# Out:
# Missing lats = user_lat    9.975913
# dtype: float64 %
